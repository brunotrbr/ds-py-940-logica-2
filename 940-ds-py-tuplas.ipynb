# %% [markdown]
# ## Exercício 7
# Vamos criar um sistema básico de uma empresa, que cadastra e lista fucionários.
#
# Cada funcionário possui os seguintes atributos: matricula, nome completo, departamento e cargo.
#
# No sistema da empresa deve ser possível:
#
# Inserir funcionários
# Consultar um único funcionário pela matrícula
# Listar todos os funcionários
# Apagar funcionários do sistema
# Consultar funcionários por palavras chave(nome, ou parte do nome, parte do nome do departamento, etc). Neste caso é necessário informar qual campo vai ser utilizado.
# Ex:
#
# Uma empresa que contenha os departamentos ['financeiro', 'controladoria', 'curadoria'], ao consultar por "Deparamento > oria", devolve ['controladoria', 'curadoria']
#
# Obs:
#
# Para armazenar os dados no programa, pode ser utilizada uma lista. Nesse momento não estamos preocupados com otimizações e outras questões do gênero.

# %% [markdown]
# #### Step 1
# Criação do menu de navegação

# %%
def imprime_menu():
    print("Informe a opção desejada:", "\n")
    print("1 - Inserir funcionário")
    print("2 - Buscar funcionário")
    print("3 - Listar todos funcionários")
    print("4 - Apagar funcionário")
    print("0 - Sair do sistema", "\n")


imprime_menu()
opcoes = [0,1,2,3,4]
opcao = -1
opcao = int(input("Informe o número da opção desejada no menu"))
while opcao not in opcoes:
    print("Opção inválida. Informe o número da opção desejada no menu", "\n")
    imprime_menu()
    opcao = int(input("Informe o número da opção desejada no menu"))

print(opcao)

# %% [markdown]
# #### Step 2
#
# Criação da inserção do funcionário com named tuple
#
# loop geral do programa
#
# refatoração das opções, convertendo para string

# %%
from collections import namedtuple
Funcionario = namedtuple("Funcionario", ['matricula', 'nome_completo','departamento','cargo'])

def imprime_menu():
    print("Informe a opção desejada:", "\n")
    print("1 - Inserir funcionário")
    print("2 - Buscar funcionário")
    print("3 - Listar todos funcionários")
    print("4 - Apagar funcionário")
    print("0 - Sair do sistema", "\n")

def while_entrada_funcionario(texto: str) -> str:
    mensagem = f'Insira o {texto} do funcionário: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada

## Início do programa ##
opcoes = ['0','1','2','3','4']
matricula = 0
funcionarios = []

imprime_menu()
while True:
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu")

    if opcao == '0':
        print('Encerrando o programa')
        break
    if opcao == '1':
        matricula += 1
        nome = while_entrada_funcionario('nome completo')
        departamento = while_entrada_funcionario('departamento')
        cargo = while_entrada_funcionario('cargo')
        func = Funcionario(matricula=matricula, nome_completo=nome, departamento=departamento, cargo=cargo)
        funcionarios.append(func)
        print("Operação concluída com sucesso")

# %% [markdown]
# #### Step 3
#
# Criação da listagem dos funcionários

# %%
from collections import namedtuple
from typing import NamedTuple
Funcionario = namedtuple("Funcionario", ['matricula', 'nome_completo','departamento','cargo'])

def imprime_menu() -> None:
    print("Informe a opção desejada:", "\n")
    print("1 - Inserir funcionário")
    print("2 - Buscar funcionário")
    print("3 - Listar todos funcionários")
    print("4 - Apagar funcionário")
    print("0 - Sair do sistema", "\n")

def while_entrada_funcionario(texto: str) -> str:
    mensagem = f'Insira o {texto} do funcionário: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada

def imprime_funcionario(funcionario: Funcionario) -> None:
    print(f'\tMatrícula: {funcionario.matricula}')
    print(f'\tNome completo: {funcionario.nome_completo}')
    print(f'\tDepartmento: {funcionario.departamento}')
    print(f'\tCargo: {funcionario.cargo}', "\n")

## Início do programa ##
opcoes = ['0','1','2','3','4']
matricula = 0
funcionarios = []

imprime_menu()
while True:
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu")

    if opcao == '0':
        print('Encerrando o programa')
        break
    if opcao == '1':
        matricula += 1
        nome = while_entrada_funcionario('nome completo')
        departamento = while_entrada_funcionario('departamento')
        cargo = while_entrada_funcionario('cargo')
        func = Funcionario(matricula=matricula, nome_completo=nome, departamento=departamento, cargo=cargo)
        funcionarios.append(func)
        print("Operação concluída com sucesso")
    if opcao == '3':
        ### Mock de funcionario
        funcionarios = [Funcionario(1, 'Lucas Ribeiro', 'Vendas', 'Vendedor'),
                        Funcionario(2, 'Renato Augusto', 'Vendas', 'Vendedor'),
                        Funcionario(3, 'Paula Silva', 'Vendas', 'Vendedor'),
                        Funcionario(4, 'Paula Santos', 'Financeiro', 'Gerente')]
        ### Mock de funcionario
        
        print("Listagem de funcionários:")
        for func in funcionarios:
            imprime_funcionario(func)

# %% [markdown]
# #### Step 4
#
# Criação de apagar os funcionários

# %%
from collections import namedtuple
from typing import List, NamedTuple

Funcionario = namedtuple("Funcionario", ['matricula', 'nome_completo', 'departamento', 'cargo'])


def imprime_menu() -> None:
    print("Informe a opção desejada:", "\n")
    print("1 - Inserir funcionário")
    print("2 - Buscar funcionário")
    print("3 - Listar todos funcionários")
    print("4 - Apagar funcionário")
    print("0 - Sair do sistema", "\n")


def while_entrada_funcionario(texto: str) -> str:
    mensagem = f'Insira o {texto} do funcionário: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada


def imprime_funcionario(funcionario: Funcionario) -> None:
    print(f'\tMatrícula: {funcionario.matricula}')
    print(f'\tNome completo: {funcionario.nome_completo}')
    print(f'\tDepartmento: {funcionario.departamento}')
    print(f'\tCargo: {funcionario.cargo}', "\n")


def while_confirmacao(mensagem: str) -> str:
    entradas_validas = ['S', 'N']
    conf = input(mensagem).strip().upper()
    while conf not in entradas_validas:
        conf = input(f'Opção inválida. {mensagem}: ')
    return conf


# Início do programa #
opcoes = ['0', '1', '2', '3', '4']
matricula = 0
funcionarios: List[NamedTuple] = []

imprime_menu()
while True:
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu: ")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu: ")

    if opcao == '0':
        print('Encerrando o programa')
        break
    if opcao == '1':
        matricula += 1
        nome = while_entrada_funcionario('nome completo')
        departamento = while_entrada_funcionario('departamento')
        cargo = while_entrada_funcionario('cargo')
        func = Funcionario(matricula=matricula, nome_completo=nome, departamento=departamento, cargo=cargo)
        funcionarios.append(func)
        print("Operação concluída com sucesso")
    if opcao == '3':
        print("Listagem de funcionários:")
        for func in funcionarios:
            imprime_funcionario(func)
    if opcao == '4':
        # Mock de funcionario
        funcionarios = [Funcionario(1, 'Lucas Ribeiro', 'Vendas', 'Vendedor'),
                        Funcionario(2, 'Renato Augusto', 'Vendas', 'Vendedor'),
                        Funcionario(3, 'Paula Silva', 'Vendas', 'Vendedor'),
                        Funcionario(4, 'Paula Santos', 'Financeiro', 'Gerente')]
        # Mock de funcionario

        matricula_func = ''
        while not isinstance(matricula_func, int):
            try:
                matricula_func = int(input("Informe o número da matrícula do funcionário:"))
            except Exception:
                print("Erro. A matrícula é um número.")
                matricula_func = int(input("Informe o número da matrícula do funcionário:"))

        index = -1
        for idx, func in enumerate(funcionarios):
            if func.matricula == matricula_func:
                index = idx
                break

        if index == -1:
            print('Matrícula inexistente.')
        else:
            print('Funcionário:')
            imprime_funcionario(funcionarios[index])
            confirmacao = while_confirmacao('Deseja apagar o funcionário? [S/N]')
            if confirmacao == 'S':
                removido = funcionarios.pop(index)
                print('Operação concluída com sucesso.')
                print(removido)
                print(funcionarios)
            else:
                print('Operação cancelada.')

# %% [markdown]
# #### Step 5
#
# Criação de consulta dos funcionários.
#
# Correção no loop de imprime menu, colocando dentro do while True.
#
# Refatoração da consulta de matrícula do funcionário, para reutilizar ela.
#
# Refatoração dos títulos dos menus

# %%
from collections import namedtuple
from typing import List, NamedTuple

Funcionario = namedtuple("Funcionario", ['matricula', 'nome_completo', 'departamento', 'cargo'])


def imprime_menu() -> None:
    print("Menu principal:", "\n")
    print("1 - Inserir funcionário")
    print("2 - Buscar funcionário")
    print("3 - Listar todos funcionários")
    print("4 - Apagar funcionário")
    print("0 - Sair do sistema", "\n")


def while_entrada_funcionario(texto: str) -> str:
    mensagem = f'Insira {texto} do funcionário: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada


def imprime_funcionario(funcionario: Funcionario) -> None:
    print(f'\tMatrícula: {funcionario.matricula}')
    print(f'\tNome completo: {funcionario.nome_completo}')
    print(f'\tDepartmento: {funcionario.departamento}')
    print(f'\tCargo: {funcionario.cargo}', "\n")


def while_confirmacao(mensagem: str) -> str:
    entradas_validas = ['S', 'N']
    conf = input(mensagem).strip().upper()
    while conf not in entradas_validas:
        conf = input(f'Opção inválida. {mensagem}: ')
    return conf


def submenu_busca() -> None:
    print()
    print("Buscar funcionários:", "\n")
    print("1 - Buscar funcionário por matrícula")
    print("2 - Buscar funcionário por palavra chave")
    print("0 - Voltar ao menu principal")


def while_matricula() -> int:
    matricula_func = ''
    while not isinstance(matricula_func, int):
        try:
            matricula_func = int(input("Informe o número da matrícula do funcionário:"))
        except Exception:
            print("Erro. A matrícula é um número.")
            matricula_func = int(input("Informe o número da matrícula do funcionário:"))
    return matricula_func


def submenu_campos() -> None:
    print()
    print("Campos disponíveis para busca:", "\n")
    print("1 - Nome completo")
    print("2 - Departamento")
    print("3 - Cargo")
    print("0 - Voltar ao menu anterior")


# Início do programa #
opcoes = ['0', '1', '2', '3', '4']
matricula = 0
funcionarios: List[NamedTuple] = []

while True:
    print()
    imprime_menu()
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu: ")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu: ")

    if opcao == '0':
        print('Encerrando o programa')
        break
    elif opcao == '1':
        matricula += 1
        nome = while_entrada_funcionario('o nome completo')
        departamento = while_entrada_funcionario('o departamento')
        cargo = while_entrada_funcionario('o cargo')
        func = Funcionario(matricula=matricula, nome_completo=nome, departamento=departamento, cargo=cargo)
        funcionarios.append(func)
    elif opcao == '2':
        # Mock de funcionario
        funcionarios = [Funcionario(1, 'Lucas Ribeiro', 'Vendas', 'Vendedor'),
                        Funcionario(2, 'Renato Augusto', 'Vendas', 'Vendedor'),
                        Funcionario(3, 'Paula Silva', 'Vendas', 'Vendedor'),
                        Funcionario(4, 'Paula Santos', 'Financeiro', 'Gerente')]
        # Mock de funcionario

        submenu_busca()
        opcao_submenu_busca = '-1'
        opcao_submenu_busca = input("Informe o número da opção desejada no menu: ")
        while opcao_submenu_busca not in opcoes[0:3]:
            print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
            submenu_busca()
            opcao_submenu_busca = input("Informe o número da opção desejada no menu: ")

        if opcao_submenu_busca == '1':
            matricula_desejada = while_matricula()
            for func in funcionarios:
                if func.matricula == matricula_desejada:
                    print('Funcionário:')
                    imprime_funcionario(func)
        elif opcao_submenu_busca == '2':
            submenu_campos()
            opcao_submenu_campos = '-1'
            opcao_submenu_campos = input("Informe o número da opção desejada no menu: ")
            while opcao_submenu_campos not in opcoes[0:4]:
                print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
                submenu_campos()
                opcao_submenu_campos = input("Informe o número da opção desejada no menu: ")

            if opcao_submenu_campos == '1':
                pesquisavel = while_entrada_funcionario('o nome completo ou parte do nome completo')
                for func in funcionarios:
                    if pesquisavel.lower() in func.nome_completo.lower():
                        imprime_funcionario(func)
            elif opcao_submenu_campos == '2':
                pesquisavel = while_entrada_funcionario('o departamento ou parte do nome do departamento')
                for func in funcionarios:
                    if pesquisavel.lower() in func.departamento.lower():
                        imprime_funcionario(func)
            elif opcao_submenu_campos == '3':
                pesquisavel = while_entrada_funcionario('o cargo ou parte do nome do cargo')
                for func in funcionarios:
                    if pesquisavel.lower() in func.cargo.lower():
                        imprime_funcionario(func)
            else:
                print('Voltando ao menu anterior')
        else:
            print('Voltando ao menu principal')
    elif opcao == '3':
        print("Listagem de funcionários:")
        for func in funcionarios:
            imprime_funcionario(func)
    elif opcao == '4':
        matr_func = while_matricula()
        index = -1
        for idx, func in enumerate(funcionarios):
            if func.matricula == matr_func:
                index = idx
                break

        if index == -1:
            print('Matrícula inexistente.')
        else:
            print('Funcionário:')
            imprime_funcionario(funcionarios[index])
            confirmacao = while_confirmacao('Deseja apagar o funcionário? [S/N]')
            if confirmacao == 'S':
                removido = funcionarios.pop(index)
                print('Operação concluída com sucesso.')
                print(removido)
                print(funcionarios)
            else:
                print('Operação cancelada.')

# %% [markdown]
# ### Versão final

# %%
from collections import namedtuple
from typing import List, NamedTuple

Funcionario = namedtuple("Funcionario", ['matricula', 'nome_completo', 'departamento', 'cargo'])


def imprime_menu() -> None:
    print("Menu principal:", "\n")
    print("1 - Inserir funcionário")
    print("2 - Buscar funcionário")
    print("3 - Listar todos funcionários")
    print("4 - Apagar funcionário")
    print("0 - Sair do sistema", "\n")


def while_entrada_funcionario(texto: str) -> str:
    mensagem = f'Insira {texto} do funcionário: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada


def imprime_funcionario(funcionario: Funcionario) -> None:
    print(f'\tMatrícula: {funcionario.matricula}')
    print(f'\tNome completo: {funcionario.nome_completo}')
    print(f'\tDepartmento: {funcionario.departamento}')
    print(f'\tCargo: {funcionario.cargo}', "\n")


def while_confirmacao(mensagem: str) -> str:
    entradas_validas = ['S', 'N']
    conf = input(mensagem).strip().upper()
    while conf not in entradas_validas:
        conf = input(f'Opção inválida. {mensagem}: ')
    return conf


def submenu_busca() -> None:
    print()
    print("Buscar funcionários:", "\n")
    print("1 - Buscar funcionário por matrícula")
    print("2 - Buscar funcionário por palavra chave")
    print("0 - Voltar ao menu principal")


def while_matricula() -> int:
    matricula_func = ''
    while not isinstance(matricula_func, int):
        try:
            matricula_func = int(input("Informe o número da matrícula do funcionário:"))
        except Exception:
            print("Erro. A matrícula é um número.")
            matricula_func = int(input("Informe o número da matrícula do funcionário:"))
    return matricula_func


def submenu_campos() -> None:
    print()
    print("Campos disponíveis para busca:", "\n")
    print("1 - Nome completo")
    print("2 - Departamento")
    print("3 - Cargo")
    print("0 - Voltar ao menu anterior")


# Início do programa #
opcoes = ['0', '1', '2', '3', '4']
matricula = 0
funcionarios: List[NamedTuple] = []

while True:
    print()
    imprime_menu()
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu: ")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu: ")

    if opcao == '0':
        print('Encerrando o programa')
        break
    elif opcao == '1':
        matricula += 1
        nome = while_entrada_funcionario('o nome completo')
        departamento = while_entrada_funcionario('o departamento')
        cargo = while_entrada_funcionario('o cargo')
        func = Funcionario(matricula=matricula, nome_completo=nome, departamento=departamento, cargo=cargo)
        funcionarios.append(func)
    elif opcao == '2':
        submenu_busca()
        opcao_submenu_busca = '-1'
        opcao_submenu_busca = input("Informe o número da opção desejada no menu: ")
        while opcao_submenu_busca not in opcoes[0:3]:
            print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
            submenu_busca()
            opcao_submenu_busca = input("Informe o número da opção desejada no menu: ")

        if opcao_submenu_busca == '1':
            matricula_desejada = while_matricula()
            for func in funcionarios:
                if func.matricula == matricula_desejada:
                    print('Funcionário:')
                    imprime_funcionario(func)
        elif opcao_submenu_busca == '2':
            submenu_campos()
            opcao_submenu_campos = '-1'
            opcao_submenu_campos = input("Informe o número da opção desejada no menu: ")
            while opcao_submenu_campos not in opcoes[0:4]:
                print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
                submenu_campos()
                opcao_submenu_campos = input("Informe o número da opção desejada no menu: ")

            if opcao_submenu_campos == '1':
                pesquisavel = while_entrada_funcionario('o nome completo ou parte do nome completo')
                for func in funcionarios:
                    if pesquisavel.lower() in func.nome_completo.lower():
                        imprime_funcionario(func)
            elif opcao_submenu_campos == '2':
                pesquisavel = while_entrada_funcionario('o departamento ou parte do nome do departamento')
                for func in funcionarios:
                    if pesquisavel.lower() in func.departamento.lower():
                        imprime_funcionario(func)
            elif opcao_submenu_campos == '3':
                pesquisavel = while_entrada_funcionario('o cargo ou parte do nome do cargo')
                for func in funcionarios:
                    if pesquisavel.lower() in func.cargo.lower():
                        imprime_funcionario(func)
            else:
                print('Voltando ao menu anterior')
        else:
            print('Voltando ao menu principal')
    elif opcao == '3':
        print("Listagem de funcionários:")
        for func in funcionarios:
            imprime_funcionario(func)
    elif opcao == '4':
        matr_func = while_matricula()
        index = -1
        for idx, func in enumerate(funcionarios):
            if func.matricula == matr_func:
                index = idx
                break

        if index == -1:
            print('Matrícula inexistente.')
        else:
            print('Funcionário:')
            imprime_funcionario(funcionarios[index])
            confirmacao = while_confirmacao('Deseja apagar o funcionário? [S/N]')
            if confirmacao == 'S':
                removido = funcionarios.pop(index)
                print('Operação concluída com sucesso.')
                print(removido)
                print(funcionarios)
            else:
                print('Operação cancelada.')

# %% [markdown]
# ## Exercício 8
# Crie uma agenda telefônica no console para que seja possível adicionar contatos, contendo as seguintes características
#
# Contato
#
# Nome do contato
# Telefone
# Email
# Na agenda deve ser possível:
#
# Adicionar um contato
# Remover um contato
# Listar todos os contatos (trazendo todos os dados do contato)
# Listar todos os contatos de forma resumida (trazendo somente o nome do contato)
# Buscar contatos por nome
# Obs:
#
# Para armazenar os dados no programa, pode ser utilizada uma lista. Nesse momento não estamos preocupados com otimizações e outras questões do gênero.

# %% [markdown]
# ### Step 1
# Criação do menu inicial

# %%
from typing import List, Dict

def imprime_menu():
    print("Menu principal", "\n")
    print("1 - Inserir contato")
    print("2 - Buscar contato")
    print("3 - Listar todos os contatos")
    print("4 - Listar todos os contatos resumidamente")
    print("5 - Apagar contato")
    print("0 - Sair do sistema", "\n")

# Início do programa #
opcoes = ['0','1','2','3','4', '5']
opcao = '-1'
contatos: Dict = {}

while True:
    print()
    imprime_menu()
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu: ")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu: ")

    if opcao == '0':
        print('Encerrando o programa')
        break
    elif opcao == '1':
        print('Inserir contato')
    elif opcao == '2':
        print('Busca contato')
        break
    elif opcao == '3':
        print('Listar contato')
        break
    elif opcao == '4':
        print('Listar resumidamente')
        break
    elif opcao == '5':
        print('Apagar contato')
        break

# %% [markdown]
# ### Step 2
#
# Criação da inserção de contatos

# %%
from typing import List, Dict

def imprime_menu():
    print("Menu principal", "\n")
    print("1 - Inserir contato")
    print("2 - Buscar contato")
    print("3 - Listar todos os contatos")
    print("4 - Listar todos os contatos resumidamente")
    print("5 - Apagar contato")
    print("0 - Sair do sistema", "\n")

def while_entrada_contato(texto: str) -> str:
    mensagem = f'Insira {texto} do contato: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada

def while_confirmacao(mensagem: str) -> str:
    entradas_validas = ['S', 'N']
    conf = input(mensagem).strip().upper()
    while conf not in entradas_validas:
        conf = input(f'Opção inválida. {mensagem}: ')
    return conf

# Início do programa #
opcoes = ['0','1','2','3','4', '5']
opcao = '-1'
contatos: Dict = {}

while True:
    print()
    imprime_menu()
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu: ")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu: ")

    if opcao == '0':
        print('Encerrando o programa')
        break
    elif opcao == '1':
        nome = while_entrada_contato('o nome completo')
        telefone = while_entrada_contato('o telefone')
        email = while_entrada_contato('o email')
        cont = {'nome': nome, 'telefone': telefone, 'email': email}
        contato_existe = nome in contatos.keys()
        if contato_existe is True:
            confirmacao = while_confirmacao('Deseja sobrescrever o contato? [S/N]')
        
        if contato_existe is False:
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'S':
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'N':
            print('Operação cancelada.')
        print(contatos)
    elif opcao == '2':
        print('Busca contato')
        break
    elif opcao == '3':
        print('Listar contato')
        break
    elif opcao == '4':
        print('Listar resumidamente')
        break
    elif opcao == '5':
        print('Apagar contato')
        break

# %% [markdown]
# ### Step 3
#
# Criação da busca de contatos

# %%
from typing import List, Dict

def imprime_menu():
    print("Menu principal", "\n")
    print("1 - Inserir contato")
    print("2 - Buscar contato")
    print("3 - Listar todos os contatos")
    print("4 - Listar todos os contatos resumidamente")
    print("5 - Apagar contato")
    print("0 - Sair do sistema", "\n")

def while_entrada_contato(texto: str) -> str:
    mensagem = f'Insira {texto} do contato: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada

def while_confirmacao(mensagem: str) -> str:
    entradas_validas = ['S', 'N']
    conf = input(mensagem).strip().upper()
    while conf not in entradas_validas:
        conf = input(f'Opção inválida. {mensagem}: ')
    return conf

def imprime_contato(contato: Dict) -> None:
    print(f'\tNome completo: {contato["nome"]}')
    print(f'\tTelefone: {contato["telefone"]}')
    print(f'\tEmail: {contato["email"]}', '\n')
    

# Início do programa #
opcoes = ['0','1','2','3','4', '5']
opcao = '-1'
contatos: List[Dict] = []

while True:
    print()
    imprime_menu()
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu: ")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu: ")

    if opcao == '0':
        print('Encerrando o programa')
        break
    elif opcao == '1':
        nome = while_entrada_contato('o nome completo')
        telefone = while_entrada_contato('o telefone')
        email = while_entrada_contato('o email')
        cont = {'nome': nome, 'telefone': telefone, 'email': email}
        contato_existe = nome in contatos.keys()
        if contato_existe is True:
            confirmacao = while_confirmacao('Deseja sobrescrever o contato? [S/N]')
        
        if contato_existe is False:
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'S':
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'N':
            print('Operação cancelada.')
        print(contatos)
    elif opcao == '2':
        # Mock de contatos
        contatos = {
            'jose': {'nome':'jose', 'telefone': 111, 'email': 'jose@jose.com' },
            'josias': {'nome':'josias', 'telefone': 222, 'email': 'josias@josias.com' },
            'pedro': {'nome':'pedro', 'telefone': 333, 'email': 'pedro@pedro.com' }
        }
        # Mock de contatos
        contato_pesquisado = while_entrada_contato('o nome ou parte do nome').upper()
        print('Contatos localizados:','\n')
        for k,v in contatos.items():
            if contato_pesquisado in k.upper():
                imprime_contato(v)
    elif opcao == '3':
        print('Listar contatos')
        break
    elif opcao == '4':
        print('Listar resumidamente')
        break
    elif opcao == '5':
        print('Apagar contato')
        break

# %% [markdown]
# ### Step 4
#
# Listar contatos

# %%
from typing import List, Dict

def imprime_menu():
    print("Menu principal", "\n")
    print("1 - Inserir contato")
    print("2 - Buscar contato")
    print("3 - Listar todos os contatos")
    print("4 - Listar todos os contatos resumidamente")
    print("5 - Apagar contato")
    print("0 - Sair do sistema", "\n")

def while_entrada_contato(texto: str) -> str:
    mensagem = f'Insira {texto} do contato: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada

def while_confirmacao(mensagem: str) -> str:
    entradas_validas = ['S', 'N']
    conf = input(mensagem).strip().upper()
    while conf not in entradas_validas:
        conf = input(f'Opção inválida. {mensagem}: ')
    return conf

def imprime_contato(contato: Dict) -> None:
    print(f'\tNome completo: {contato["nome"]}')
    print(f'\tTelefone: {contato["telefone"]}')
    print(f'\tEmail: {contato["email"]}', '\n')

# Início do programa #
opcoes = ['0','1','2','3','4', '5']
opcao = '-1'
contatos: List[Dict] = []

while True:
    print()
    imprime_menu()
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu: ")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu: ")

    if opcao == '0':
        print('Encerrando o programa')
        break
    elif opcao == '1':
        nome = while_entrada_contato('o nome completo')
        telefone = while_entrada_contato('o telefone')
        email = while_entrada_contato('o email')
        cont = {'nome': nome, 'telefone': telefone, 'email': email}
        contato_existe = nome in contatos.keys()
        if contato_existe is True:
            confirmacao = while_confirmacao('Deseja sobrescrever o contato? [S/N]')
        
        if contato_existe is False:
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'S':
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'N':
            print('Operação cancelada.')
        print(contatos)
    elif opcao == '2':
        contato_pesquisado = while_entrada_contato('o nome ou parte do nome').upper()
        print('Contatos localizados:','\n')
        for k,v in contatos.items():
            if contato_pesquisado in k.upper():
                imprime_contato(v)
    elif opcao == '3':
        # Mock de contatos
        contatos = {
            'jose': {'nome':'jose', 'telefone': 111, 'email': 'jose@jose.com' },
            'josias': {'nome':'josias', 'telefone': 222, 'email': 'josias@josias.com' },
            'pedro': {'nome':'pedro', 'telefone': 333, 'email': 'pedro@pedro.com' }
        }
        # Mock de contatos
        print('Contatos', '\n')
        for v in contatos.values():
            imprime_contato(v)
    elif opcao == '4':
        print('Listar resumidamente')
        break
    elif opcao == '5':
        print('Apagar contato')
        break

# %% [markdown]
# ### step 4
#
# Listar contatos resumidamente

# %%
from typing import List, Dict

def imprime_menu():
    print("Menu principal", "\n")
    print("1 - Inserir contato")
    print("2 - Buscar contato")
    print("3 - Listar todos os contatos")
    print("4 - Listar todos os contatos resumidamente")
    print("5 - Apagar contato")
    print("0 - Sair do sistema", "\n")

def while_entrada_contato(texto: str) -> str:
    mensagem = f'Insira {texto} do contato: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada

def while_confirmacao(mensagem: str) -> str:
    entradas_validas = ['S', 'N']
    conf = input(mensagem).strip().upper()
    while conf not in entradas_validas:
        conf = input(f'Opção inválida. {mensagem}: ')
    return conf

def imprime_contato(contato: Dict) -> None:
    print(f'\tNome completo: {contato["nome"]}')
    print(f'\tTelefone: {contato["telefone"]}')
    print(f'\tEmail: {contato["email"]}', '\n')

# Início do programa #
opcoes = ['0','1','2','3','4', '5']
opcao = '-1'
contatos: List[Dict] = []

while True:
    print()
    imprime_menu()
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu: ")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu: ")

    if opcao == '0':
        print('Encerrando o programa')
        break
    elif opcao == '1':
        nome = while_entrada_contato('o nome completo')
        telefone = while_entrada_contato('o telefone')
        email = while_entrada_contato('o email')
        cont = {'nome': nome, 'telefone': telefone, 'email': email}
        contato_existe = nome in contatos.keys()
        if contato_existe is True:
            confirmacao = while_confirmacao('Deseja sobrescrever o contato? [S/N]')
        
        if contato_existe is False:
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'S':
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'N':
            print('Operação cancelada.')
        print(contatos)
    elif opcao == '2':
        contato_pesquisado = while_entrada_contato('o nome ou parte do nome').upper()
        print('Contatos localizados:','\n')
        for k,v in contatos.items():
            if contato_pesquisado in k.upper():
                imprime_contato(v)
    elif opcao == '3':
        for v in contatos.values():
            imprime_contato(v)
    elif opcao == '4':
        # Mock de contatos
        contatos = {
            'jose': {'nome':'jose', 'telefone': 111, 'email': 'jose@jose.com' },
            'josias': {'nome':'josias', 'telefone': 222, 'email': 'josias@josias.com' },
            'pedro': {'nome':'pedro', 'telefone': 333, 'email': 'pedro@pedro.com' }
        }
        # Mock de contatos
        print('Contatos (somente nome)', '\n')
        for v in contatos.values():
            print(f'Nome: {v["nome"]}')
    elif opcao == '5':
        print('Apagar contato')
        break

# %% [markdown]
# ### Step 5
#
# Apagar contato

# %%
from typing import List, Dict

def imprime_menu():
    print("Menu principal", "\n")
    print("1 - Inserir contato")
    print("2 - Buscar contato")
    print("3 - Listar todos os contatos")
    print("4 - Listar todos os contatos resumidamente")
    print("5 - Apagar contato")
    print("0 - Sair do sistema", "\n")

def while_entrada_contato(texto: str) -> str:
    mensagem = f'Insira {texto} do contato: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada

def while_confirmacao(mensagem: str) -> str:
    entradas_validas = ['S', 'N']
    conf = input(mensagem).strip().upper()
    while conf not in entradas_validas:
        conf = input(f'Opção inválida. {mensagem}: ')
    return conf

def imprime_contato(contato: Dict) -> None:
    print(f'\tNome completo: {contato["nome"]}')
    print(f'\tTelefone: {contato["telefone"]}')
    print(f'\tEmail: {contato["email"]}', '\n')

# Início do programa #
opcoes = ['0','1','2','3','4', '5']
opcao = '-1'
contatos: List[Dict] = []

while True:
    print()
    imprime_menu()
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu: ")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu: ")

    if opcao == '0':
        print('Encerrando o programa')
        break
    elif opcao == '1':
        nome = while_entrada_contato('o nome completo')
        telefone = while_entrada_contato('o telefone')
        email = while_entrada_contato('o email')
        cont = {'nome': nome, 'telefone': telefone, 'email': email}
        contato_existe = nome in contatos.keys()
        if contato_existe is True:
            confirmacao = while_confirmacao('Deseja sobrescrever o contato? [S/N]')
        
        if contato_existe is False:
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'S':
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'N':
            print('Operação cancelada.')
        print(contatos)
    elif opcao == '2':
        contato_pesquisado = while_entrada_contato('o nome ou parte do nome').upper()
        print('Contatos localizados:','\n')
        for k,v in contatos.items():
            if contato_pesquisado in k.upper():
                imprime_contato(v)
    elif opcao == '3':
        for v in contatos.values():
            imprime_contato(v)
    elif opcao == '4':
        print('Contatos (somente nome)', '\n')
        for v in contatos.values():
            print(f'Nome: {v["nome"]}')
    elif opcao == '5':
        # Mock de contatos
        contatos = {
            'jose': {'nome':'jose', 'telefone': 111, 'email': 'jose@jose.com' },
            'josias': {'nome':'josias', 'telefone': 222, 'email': 'josias@josias.com' },
            'pedro': {'nome':'pedro', 'telefone': 333, 'email': 'pedro@pedro.com' }
        }
        # Mock de contatos
        nome = while_entrada_contato('o nome')
        contagem = 0
        for k in contatos.keys():
            if nome.upper() in k.upper():
                contagem += 1
        if contagem == 0:
            print('Não foram encontrados contatos com esse nome. Operação cancelada.')
        elif contagem > 1:
            print('Foram encontrados múltiplos contatos com esse nome. Operação cancelada.')
        else:
            imprime_contato(contatos[nome])
            confirmacao = while_confirmacao('Deseja apagar o contato? [S/N]')
            if confirmacao == 'S':
                removido = contatos.pop(nome)
                print('Operação finalizada com sucesso.')
            else:
                print('Operação cancelada')
# Out:
# Menu principal
#
# 1 - Inserir contato
# 2 - Buscar contato
# 3 - Listar todos os contatos
# 4 - Listar todos os contatos resumidamente
# 5 - Apagar contato
# 0 - Sair do sistema
#
# Foram encontrados múltiplos contatos com esse nome. Operação cancelada.
#
# Menu principal
#
# 1 - Inserir contato
# 2 - Buscar contato
# 3 - Listar todos os contatos
# 4 - Listar todos os contatos resumidamente
# 5 - Apagar contato
# 0 - Sair do sistema
#
# 	Nome completo: pedro
# 	Telefone: 333
# 	Email: pedro@pedro.com
#
# Operação cancelada
#
# Menu principal
#
# 1 - Inserir contato
# 2 - Buscar contato
# 3 - Listar todos os contatos
# 4 - Listar todos os contatos resumidamente
# 5 - Apagar contato
# 0 - Sair do sistema
#
# 	Nome completo: pedro
# 	Telefone: 333
# 	Email: pedro@pedro.com
#
# Operação finalizada com sucesso.
#
# Menu principal
#
# 1 - Inserir contato
# 2 - Buscar contato
# 3 - Listar todos os contatos
# 4 - Listar todos os contatos resumidamente
# 5 - Apagar contato
# ...

# %% [markdown]
# ### Versão final

# %%
from typing import List, Dict

def imprime_menu():
    print("Menu principal", "\n")
    print("1 - Inserir contato")
    print("2 - Buscar contato")
    print("3 - Listar todos os contatos")
    print("4 - Listar todos os contatos resumidamente")
    print("5 - Apagar contato")
    print("0 - Sair do sistema", "\n")

def while_entrada_contato(texto: str) -> str:
    mensagem = f'Insira {texto} do contato: '
    entrada = input(mensagem).strip()
    while entrada == '':
        entrada = input(mensagem).strip()
    return entrada

def while_confirmacao(mensagem: str) -> str:
    entradas_validas = ['S', 'N']
    conf = input(mensagem).strip().upper()
    while conf not in entradas_validas:
        conf = input(f'Opção inválida. {mensagem}: ')
    return conf

def imprime_contato(contato: Dict) -> None:
    print(f'\tNome completo: {contato["nome"]}')
    print(f'\tTelefone: {contato["telefone"]}')
    print(f'\tEmail: {contato["email"]}', '\n')

# Início do programa #
opcoes = ['0','1','2','3','4', '5']
opcao = '-1'
contatos: List[Dict] = []

while True:
    print()
    imprime_menu()
    opcao = '-1'
    opcao = input("Informe o número da opção desejada no menu: ")
    while opcao not in opcoes:
        print("Opção inválida. Informe o número da opção desejada no menu: ", "\n")
        imprime_menu()
        opcao = input("Informe o número da opção desejada no menu: ")

    if opcao == '0':
        print('Encerrando o programa')
        break
    elif opcao == '1':
        nome = while_entrada_contato('o nome completo')
        telefone = while_entrada_contato('o telefone')
        email = while_entrada_contato('o email')
        cont = {'nome': nome, 'telefone': telefone, 'email': email}
        contato_existe = nome in contatos.keys()
        if contato_existe is True:
            confirmacao = while_confirmacao('Deseja sobrescrever o contato? [S/N]')
        
        if contato_existe is False:
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'S':
            contatos.update({nome: cont})
            print('Operação concluída com sucesso.')
        elif contato_existe is True and confirmacao == 'N':
            print('Operação cancelada.')
        print(contatos)
    elif opcao == '2':
        contato_pesquisado = while_entrada_contato('o nome ou parte do nome').upper()
        print('Contatos localizados:','\n')
        for k,v in contatos.items():
            if contato_pesquisado in k.upper():
                imprime_contato(v)
    elif opcao == '3':
        for v in contatos.values():
            imprime_contato(v)
    elif opcao == '4':
        print('Contatos (somente nome)', '\n')
        for v in contatos.values():
            print(f'Nome: {v["nome"]}')
    elif opcao == '5':
        nome = while_entrada_contato('o nome')
        contagem = 0
        for k in contatos.keys():
            if nome.upper() in k.upper():
                contagem += 1
        if contagem == 0:
            print('Não foram encontrados contatos com esse nome. Operação cancelada.')
        elif contagem > 1:
            print('Foram encontrados múltiplos contatos com esse nome. Operação cancelada.')
        else:
            imprime_contato(contatos[nome])
            confirmacao = while_confirmacao('Deseja apagar o contato? [S/N]')
            if confirmacao == 'S':
                removido = contatos.pop(nome)
                print('Operação finalizada com sucesso.')
            else:
                print('Operação cancelada')
